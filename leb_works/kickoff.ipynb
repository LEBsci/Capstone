# %%
import pandas as pd

# %%
# Import one data file
df = pd.read_csv('/workspaces/Capstone/data/2024_03_Marc_BicingNou_ESTACIONS.csv')
# Out:
# /tmp/ipykernel_15732/695027016.py:2: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/workspaces/Capstone/data/2024_03_Marc_BicingNou_ESTACIONS.csv')

# %%
df
# Out:
#          station_id  num_bikes_available  \
# 0               1.0                 17.0
# 1               2.0                  8.0
# 2               3.0                 20.0
# 3               4.0                  3.0
# 4               5.0                  9.0
# ...             ...                  ...
# 4533443       515.0                 13.0
# 4533444       516.0                  5.0
# 4533445       517.0                 17.0
# 4533446       518.0                  1.0
# 4533447       519.0                  2.0
#
#          num_bikes_available_types.mechanical  \
# 0                                         6.0
# 1                                         4.0
# 2                                        20.0
# 3                                         1.0
# 4                                         8.0
# ...                                       ...
# 4533443                                  12.0
# 4533444                                   2.0
# ...
